# %%
# !pip install git+https://github.com/huggingface/transformers.git

# %%
# !cd /kaggle/working/transformers && pip install .

# %%
# !pip install evaluate datasets tokenizers

# %%
# !python /kaggle/working/transformers/examples/pytorch/text-classification/run_classification.py \
    --model_name_or_path PartAI/TookaBERT-Large \
    --dataset_name ParsiAI/snappfood-sentiment-analysis \
    --shuffle_train_dataset \
    --metric_name accuracy \
    --text_column_name "comment" \
    --text_column_delimiter "," \
    --label_column_name label \
    --do_train \
    --do_eval \
    --max_seq_length 512 \
    --per_device_train_batch_size 10 \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --output_dir /kaggle/working/snapfood
